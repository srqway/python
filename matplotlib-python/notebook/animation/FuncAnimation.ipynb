# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %matplotlib inline

plt.rcParams["animation.html"] = "jshtml"

# %% [markdown]
# # basic

# %%
x = range(0, 10)
y = range(-5, 5)
fig, ax = plt.subplots()
line, = ax.plot([0, 10],[-5, 5])

animate = lambda i: line.set_data(x[:i], y[:i])

ani = animation.FuncAnimation(fig, animate, frames=len(x) + 1)
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0180b0ba289349099ee6ca1f6980f871">
#     <br>
#     <input id="_anim_slider0180b0ba289349099ee6ca1f6980f871" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0180b0ba289349099ee6ca1f6980f871.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0180b0ba289349099ee6ca1f6980f871.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0180b0ba289349099ee6ca1f6980f871" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0180b0ba289349099ee6ca1f6980f871";
#     var slider_id = "_anim_slider0180b0ba289349099ee6ca1f6980f871";
#     var loop_select_id = "_anim_loop_select0180b0ba289349099ee6ca1f6980f871";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAADbFJREFUeJzt3H+o3QX9x/HX9XvaH4YWsS0378Zt\
# rPR6tfbjyvojQp3X1RiTthGTBeY2pDDIpKD+sz90ayS5MogLFWOCF/qnieaoJhWsZBwclUxl0S7c\
# e9O8I8VfydzlfP/40liatm/t3M953z0ef+18ds/l9YHtPO/ncw63r9PpdAIAxVzU9AAA+E8IGAAl\
# CRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJ\
# GAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkY\
# ACUJGAAlCRgAJQkYACW1mh7QLfPnz8/AwEDTMwBKGR8fz8mTJ5uecU7mbMAGBgbSbrebngFQyvDw\
# cNMTzplbiACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACU\
# JGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlFQqYDMzM1m5cmU2bNjQ9BQA\
# GlYqYHv37s3g4GDTMwDoAWUCNjk5mUcffTQ7d+5segoAPaBMwO68887s2bMnF11UZjIAXVSiBo88\
# 8kgWLlyY1atXv+vXjY6OZnh4OMPDw5menp6ldQA0oa/T6XSaHvHvfOMb38j+/fvTarXyxhtv5OWX\
# X86mTZvy4IMPvuNzhoeH0263Z3ElQH2VXjtLXIHt2rUrk5OTGR8fz9jYWG644YZ3jRcAc1+JgAHA\
# W7WaHvD/dd111+W6665regYADXMFBkBJAgZASQIGQEkCBkBJAgZASQIGQEkCBkBJAgZASQIGQEkC\
# BkBJAgZASQIGQEkCBkBJAgZASQIGQEkCBkBJAgZASQIGQEkCBkBJAgZASQIGQEkCBkBJAgZASQIG\
# QEkCBkBJAgZASQIGQEkCBkBJAgZASQIGQEkCBkBJJQI2MTGR66+/PoODgxkaGsrevXubngRAw1pN\
# DzgXrVYr9913X1atWpVXXnklq1evzsjISK666qqmpwHQkBJXYIsWLcqqVauSJJdcckkGBwczNTXV\
# 8CoAmlQiYGcbHx/P0aNHs2bNmqanANCgErcQ/+HVV1/N5s2bc//99+fSSy9929+Pjo5mdHQ0STI9\
# PT3b8wCYRX2dTqfT9Ihz8eabb2bDhg1Zt25d7rrrrn/79cPDw2m327OwDGDuqPTaWeIWYqfTyY4d\
# OzI4OHhO8QJg7isRsMOHD2f//v15/PHHs2LFiqxYsSI/+9nPmp4FQINKvAf2iU98IkXudAIwS0pc\
# gQHAWwkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJ\
# GAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkYACUJGAAlCRgAJQkY\
# ACUJGAAllQnYwYMHc8UVV2T58uXZvXt303MAaFiJgM3MzOSOO+7IY489lmPHjuWhhx7KsWPHmp4F\
# QINKBOzIkSNZvnx5li1blnnz5mXr1q05cOBA07MAaFCJgE1NTWXJkiVnHvf392dqaqrBRQA0rdX0\
# gHPR6XTedqyvr+9tx0ZHRzM6OpokmZ6e7vouAJpT4gqsv78/ExMTZx5PTk5m8eLFb/u622+/Pe12\
# O+12OwsWLJjNiQDMshIBu/baa3P8+PGcOHEip06dytjYWDZu3Nj0LAAaVOIWYqvVygMPPJB169Zl\
# ZmYm27dvz9DQUNOzAGhQiYAlyfr167N+/fqmZwDQI0rcQgSAtxIwAEoSMABKEjAAS

# %%
x = np.linspace(-1, 1, 100)
y = np.sin(x**2*25)
data = np.array([x, y])

fig = plt.figure()
line, = plt.plot([], [], "r-") # start with an empty plot
plt.axis([-1.1, 1.1, -1.1, 1.1])
plt.plot([-0.5, 0.5], [0, 0], "b-", [0, 0], [-0.5, 0.5], "b-", 0, 0, "ro")
plt.grid(True)
plt.title("Marvelous animation")

# this function will be called at every iteration
def update_line(num, data, line):
    line.set_data(data[..., :num] + np.random.rand(2, num) / 25)  # we only plot the first `num` data points.
    return line,

ani = animation.FuncAnimation(fig, update_line, frames=100, fargs=(data, line), interval=100)
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img2aae02f20d67483e86cf020736378418">
#     <br>
#     <input id="_anim_slider2aae02f20d67483e86cf020736378418" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim2aae02f20d67483e86cf020736378418.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim2aae02f20d67483e86cf020736378418.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select2aae02f20d67483e86cf020736378418" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2aae02f20d67483e86cf020736378418";
#     var slider_id = "_anim_slider2aae02f20d67483e86cf020736378418";
#     var loop_select_id = "_anim_loop_select2aae02f20d67483e86cf020736378418";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X9UlHWiP/D3yCRKmvxQAhyTHzOQ\
# /JJiCGzvSX6IrHgbj4WBWo5hYVfP3Zv31spdk8zNpO2e9t5dTO+kJW7GpG4Lnn6gKOK9x9yQm3RM\
# bZcU0RlQ45e7WIKOn+8ffn2O04AywDw8T71f53gO83k+n3nefJh4M89MoBFCCBAREanMiOEOQERE\
# NBAsMCIiUiUWGBERqRILjIiIVIkFRkREqsQCIyIiVWKBERGRKrHAiIhIlVhgRESkSiwwIiJSJRYY\
# ERGpEguMiIhUiQVGRESqxAIjIiJVYoEREZEqscCIiEiVWGBERKRKLDAiIlIlFhjRLRYvXoyXXnpp\
# uGP025gxY3D69GlZzvXcc8/h17/+tSznIuoPFhgNm9DQUIwcORKtra1O4wkJCdBoNDhz5szwBFOR\
# rq4uhIeHD/n9bt26Ff/wD//gNLZp0yasXr16yM9FNFAsMBpWYWFhKCsrk24fO3YM33///YDv79q1\
